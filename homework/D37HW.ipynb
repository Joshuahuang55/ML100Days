# %% [markdown]
# ## 作業
# 在鐵達尼資料集中，
# 透過進階補值方法 KNN，將鐵達尼號中的 Titanic_train
# .csv 中的 age 的遺失值進行補值。
# * step1: 觀察 Age 和 Pclass 與 Sex 是否有關連性?
# * step2: 如果有關連性，運用 KNN ，取出 Age 、 Pclass、 Sex的資料，以 Sex 與 Pclass 補 Age 遺失值。

# %%
# import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display

# %% [markdown]
# ## 讀入資料

# %% [markdown]
# ## 觀察 Age

# %%
df_train = pd.read_csv("Titanic_train.csv")
df_train["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#轉換Sex
from sklearn import preprocessing
ori_train = pd.DataFrame(df_train)
le = preprocessing.LabelEncoder()
ori_train['Sex']=le.fit_transform(ori_train['Sex'])
display(ori_train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
#計算資料點的倆倆距離
from sklearn.metrics.pairwise import nan_euclidean_distances

ori_train = ori_train.drop(["Name","Ticket","Cabin","Embarked"], axis=1)

display(pd.DataFrame(nan_euclidean_distances(ori_train)))
# Out:
#             0           1           2           3           4           5    \
# 0      0.000000   66.055004    4.843101   47.814459   13.661625    5.602039
# 1     66.055004    0.000000   64.531188   18.537324   63.430673   67.358153
# 2      4.843101   64.531188    0.000000   46.127873    9.328217    3.591165
# 3     47.814459   18.537324   46.127873    0.000000   45.138703   47.855513
# 4     13.661625   63.430673    9.328217   45.138703    0.000000    1.154721
# ..          ...         ...         ...         ...         ...         ...
# 886  886.033895  886.987566  884.016830  883.948534  882.050737  941.841738
# 887  887.300717  887.165323  885.305205  884.447065  883.421079  943.182482
# 888  949.472900  949.626107  947.322860  946.641053  945.182770  944.106381
# 889  889.303414  889.041231  887.277468  886.347906  885.320734  945.319323
# 890  890.056880  891.291468  888.021413  888.167564  886.005130  946.105099
#
# ...

# %%
# KNN
# 設定 k 值
value_neighbors = 1
from sklearn.impute import KNNImputer
#初始化: Initialize KNNImputer
ori_train = ori_train.drop(["PassengerId","Survived","SibSp","Parch","Fare"], axis=1)

imputer = KNNImputer(n_neighbors=value_neighbors)
df_filled = pd.DataFrame(imputer.fit_transform(ori_train))
df_filled
# Out:
#        0    1     2
# 0    3.0  1.0  22.0
# 1    1.0  0.0  38.0
# 2    3.0  0.0  26.0
# 3    1.0  0.0  35.0
# 4    3.0  1.0  35.0
# ..   ...  ...   ...
# 886  2.0  1.0  27.0
# 887  1.0  0.0  19.0
# 888  3.0  0.0  26.0
# 889  1.0  1.0  26.0
# 890  3.0  1.0  32.0
#
# [891 rows x 3 columns]
